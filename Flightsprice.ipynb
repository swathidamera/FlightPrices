# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv('flightsdata.csv')

# %%
data.head()
# Out:
#    Unnamed: 0 Source Destination    Flight_Code     Dep_Date Dep_Time  \
# 0           0   Pune   New Delhi  I5 1732, 1528  Sun, Feb 27    23:50
# 1           1   Pune   New Delhi   I5 1732, 741  Sun, Feb 27    23:50
# 2           2   Pune   New Delhi         I5 738  Fri, Mar 04    01:30
# 3           3   Pune   New Delhi         I5 732  Fri, Mar 04    17:55
# 4           4   Pune   New Delhi   I5 1426, 789  Fri, Mar 04    14:55
#
#   Arrival_Time Duration  Stops Economy_Price Premium_Price    Flight_Info  \
# 0      08:55+1     9h5m      1       ₹21,525       ₹21,735  Flight Change
# 1      14:05+1   14h15m      1       ₹21,525       ₹21,735  Flight Change
# 2        03:35     2h5m      0        ₹7,009        ₹7,345       Non Stop
# 3        20:10    2h15m      0        ₹7,009        ₹7,345       Non Stop
# 4      00:50+1    9h55m      1        ₹7,428        ₹7,954  Flight Change
#
#   Flight_Changeplace SeatsLeft_EconomyPrice SeatsLeft_PremiumPrice
# ...

# %%
data
# Out:
#       Unnamed: 0  Source Destination    Flight_Code     Dep_Date Dep_Time  \
# 0              0    Pune   New Delhi  I5 1732, 1528  Sun, Feb 27    23:50
# 1              1    Pune   New Delhi   I5 1732, 741  Sun, Feb 27    23:50
# 2              2    Pune   New Delhi         I5 738  Fri, Mar 04    01:30
# 3              3    Pune   New Delhi         I5 732  Fri, Mar 04    17:55
# 4              4    Pune   New Delhi   I5 1426, 789  Fri, Mar 04    14:55
# 5              5    Pune   New Delhi   I5 1427, 749  Fri, Mar 04    19:30
# 6              6    Pune   New Delhi   I5 1427, 722  Fri, Mar 04    19:30
# 7              7    Pune   New Delhi  I5 1427, 1528  Fri, Mar 04    19:30
# 8              8    Pune   New Delhi  I5 1732, 1528  Fri, Mar 04    23:50
# 9              9    Pune   New Delhi   I5 1732, 741  Fri, Mar 04    23:50
# 10            10    Pune   New Delhi    I5 320, 552  Fri, Mar 04    19:05
# 11            11    Pune   New Delhi         I5 738  Tue, Mar 08    01:30
# ...

# %%
data.shape
# Out:
# (2012, 15)

# %%
data.drop(columns='Unnamed: 0',inplace=True)

# %%
data['Flight_Code'].nunique()
# Out:
# 415

# %% [markdown]
# FlightCodes will not be useful, drop the column

# %%
data.drop(columns='Flight_Code',inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2012 entries, 0 to 2011
# Data columns (total 13 columns):
# Source                    2012 non-null object
# Destination               2012 non-null object
# Dep_Date                  2012 non-null object
# Dep_Time                  2012 non-null object
# Arrival_Time              2012 non-null object
# Duration                  2012 non-null object
# Stops                     2012 non-null int64
# Economy_Price             2012 non-null object
# Premium_Price             2012 non-null object
# Flight_Info               2012 non-null object
# Flight_Changeplace        1629 non-null object
# SeatsLeft_EconomyPrice    2012 non-null object
# SeatsLeft_PremiumPrice    2012 non-null object
# dtypes: int64(1), object(12)
# memory usage: 204.4+ KB

# %%
from datetime import datetime
from datetime import timedelta

# %%
for n,i in enumerate(data['Dep_Date']):
    data['Dep_Date'][n]=datetime.strptime(data['Dep_Date'][n],'%a, %b %d').replace(year=2022)

# %%
data['Dep_Date'].head()
# Out:
# 0    2022-02-27 00:00:00
# 1    2022-02-27 00:00:00
# 2    2022-03-04 00:00:00
# 3    2022-03-04 00:00:00
# 4    2022-03-04 00:00:00
# Name: Dep_Date, dtype: object

# %%
next=timedelta(days=1)

# %%
data=data.assign(Arrival_Date=data.Dep_Date+next)

# %%
data.head()
# Out:
#       Source Destination   Dep_Date   Dep_Time Arrival_Time   Duration  \
# 0 2022-02-28  2022-02-28 2022-02-28 2022-02-28   2022-02-28 2022-02-28
# 1 2022-02-28  2022-02-28 2022-02-28 2022-02-28   2022-02-28 2022-02-28
# 2 2022-02-28  2022-02-28 2022-02-28 2022-02-28   2022-02-28 2022-02-28
# 3 2022-02-28  2022-02-28 2022-02-28 2022-02-28   2022-02-28 2022-02-28
# 4 2022-02-28  2022-02-28 2022-02-28 2022-02-28   2022-02-28 2022-02-28
#
#        Stops Economy_Price Premium_Price Flight_Info Flight_Changeplace  \
# 0 2022-02-28    2022-02-28    2022-02-28  2022-02-28         2022-02-28
# 1 2022-02-28    2022-02-28    2022-02-28  2022-02-28         2022-02-28
# 2 2022-02-28    2022-02-28    2022-02-28  2022-02-28         2022-02-28
# 3 2022-02-28    2022-02-28    2022-02-28  2022-02-28         2022-02-28
# 4 2022-02-28    2022-02-28    2022-02-28  2022-02-28         2022-02-28
#
#   SeatsLeft_EconomyPrice SeatsLeft_PremiumPrice Arrival_Date
# ...

# %%
l=len(data['Arrival_Time'])

# %%
for i in range(l):
    if ('+' in data['Arrival_Time'][i]):
        data.loc[i:'Arrival_Date']=data['Dep_Date'][i]+next
    else:
        data.loc[i:'Arrival_Date']=data['Dep_Date'][i]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-58-8ad1e815a2b6> in <module>
#       1 for i in range(l):
# ----> 2     if ('+' in data['Arrival_Time'][i]):
#       3         data.loc[i:'Arrival_Date']=data['Dep_Date'][i]+next
#       4     else:
#       5         data.loc[i:'Arrival_Date']=data['Dep_Date'][i]
#
# TypeError: argument of type 'Timestamp' is not iterable

# %% [markdown]
# Not able to continue because of time constraints
